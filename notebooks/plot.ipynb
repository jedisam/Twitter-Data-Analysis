# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('cleaned_tweet_data.csv')

df["possibly_sensitive"].value_counts().plot.bar()
plt.title("Sensitivity of tweets")

plt.show()
